# %% [markdown]
# # <center><h1 style="font-size:80px; color:MidnightBlue;">﷽</h1></center>
# <center><h1 style="font-size:40px; color:MidnightBlue;">"IMPLEMENTATION OF APRIORI ALGORITHM"</h1></center>
# <center><h3 style="font-size:20px; color:MidnightBlue;">"SECOND ASSIGNMENT OF" </h3> </center>
# <center><h1 style="font-size:50px; color:MidnightBlue;">"DATA MINING "</h1></center>

# %% [markdown]
# # <center><h3 style="font-size:30px; color:MidnightBlue;">"GROUP MEMBERRS"</h3></center>
#
# <table style=" color:Green;font-size:30px; border:7px double MidnightBlue; border-collapse: collapse;border-spacing: 50px;" >
#    <tr style="background-color:#f2f0fc;">
#     <th style="text-align: center; color: MidnightBlue;" >"Sr. No."</th>
#     <th style="text-align: center; color: MidnightBlue" >"STUDENT NAME"</th>
#     <th style="text-align: center; color: MidnightBlue" >"ROLL NUMBER"</th>
#     </tr>
#   <tr style="background-color:#fff;">
#     <td style="text-align: center;" ><b>1.</b></td>
#     <td style="text-align: center;" ><b>Abdullah Shahid</b></td>
#     <td style="text-align: center;" ><b>F2019027004</b></td>
#   </tr>
#   <tr style="background-color:#fff;">
#     <td style="text-align: center;" ><b>2.</b></td>
#     <td style="text-align: center;" ><b>Syed Shahzad Mubashar</b></td>
#     <td style="text-align: center;" ><b>F2019027030</b></td>
#   </tr>
# </table>

# %% [markdown]
# <center><h1 style="font-size:30px; color:MidnightBlue;line-height:1.5">"Task For This Assignment Is To Implement And Evaluate The Apriori-Based Algorithm For Frequent Item Sets Mining."</h1></center>

# %% [markdown]
# # <center><h1 style="font-size:30px; color:Green;">"INTRODUCTION" </h1> </center>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5">The Apriori algorithm is given by R. Agrawal and R. Srikant in 1994 for finding frequent itemsets in a dataset for boolean association rules. The Name of the algorithm is Apriori because it uses prior knowledge of frequent itemset properties. </p>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5"> In this Algorithm we apply an iterative approach/level-wise search where k-frequent itemsets are used to find k+1 itemsets.</p>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5">To improve the efficiency of level-wise generation of frequent itemsets, an important property is used called Apriori property which helps by reducing the search space.</p>

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Creating A Function using Apriory Hash Table Technique"</h1></center>

# %% [markdown]
#     This Function has 14 sub functions and 2 Main Functions which are used to find the Frequent Item Sets, Their rules and it will find the Support, Confidence and Lift as well. Our Main Functions are as under:
#
# 1. <b>My_apriory</b>.
#
# 2. <b>Generate_role_and_measure_support_confidence_lift</b>
#
# <b>My_Apriory</b>
#
# This function will take two parameters and return 2-D list of frequent items set using the approach of Hash Table Algorithm that is Apriory with Hash Table Algorithm to find Frequent Items set.
#
# <b>All_Items_List:</b>
#
# A 2-D List for all the transactions which will remove the NAN Values (Null values/empty values) from our dataset.
#
# <b>Support:</b>
#
# This is an integer parameter refers to minimum support value used to find Frequent Item Sets.
#
#
# <b>GENERATING RULES AND MEASURING SUPPORT AND CONFIDENCE</b>
#
# 		This Function take three parameters and save their output in a text file which we will give as a parameter and it will return all possible rules with their support, confidence and lift value. This functions have 3 parameters as under:
#
# 1. <b>Frequent_Items.</b>
#
# 2.	<b>All_Items_List.</b>
#
# 3. <b>file_name</b>
#
# <b>Frequent Items:</b>
#
#             This parameter takes 2-D list of Frequent Items Set returned by My_Apriory function.
#
# <b>All_Items_Lis:</b>
#
#             This is a 2-D list of all transactions which we load from our Dataset.
# 			After that we have applied all the functions on 3 different data sets respectively.
#
# <b>file_name</b>
#
#             This parameter take the string for the name of that file which will save the all output.

# %% [markdown]
# # <center><h3 style="font-size:30px; color:MidnightBlue;">"Importing Libraries"</h3></center>

# %%
import sys
import re
import pandas as pd
from tabulate import tabulate

# %% [markdown]
# # <center><h3 style="font-size:25px; color:MidnightBlue;">"Our Self Made Functions for Apriori Algorithem using Hash Table"</h3></center>

# %%
# 1
#call from 13
# return frequent item list
def pass_one(all_items_list, items_subset_from_last_pass, support):
    result = []
    itemset_size = 1
    if items_subset_from_last_pass: # check null or not
        itemset_size = len(items_subset_from_last_pass[0])
    item_counts = count_unique_items(all_items_list, items_subset_from_last_pass, support) # -> 3 return 2d list & count from 1st two parameters
    frequent_items = find_frequent_items(item_counts, support) # -> 4 return 2d list itemd grater then min "support" value
    if not frequent_items: # if frequent_items is empty
        return []
    result.append(frequent_items) # add frequent_items list in result list variable
    return result



# 2
#call from 13
# applay hashing technique
def pass_two(all_items_list, ans_one):
    result = []
    frequent_items = ans_one[0] # frequent items set from pas-one   
    result.append(frequent_items)    
    itemset_size = len(frequent_items[0]) + 1 # find the length of last items subset   
    pairs = generate_pairs(frequent_items, all_items_list, itemset_size + 1) # -> 5 pairs according pass-one items-subsets
    if not pairs: # if no more possiable pairs exist
        return result 
    bucket = maping_pairs_bucket(pairs, all_items_list) # -> 7 return buckets with total items count
    candidates = [] # store possiable pairs for next possiable subset
    for outer_list in bucket.values():
        for inner_list in outer_list:
            candidates.append(inner_list)
    result.append(bucket)
    result.append(candidates)
    return result



# 3
# single call by pass-one 
# return 2d list from original items set orr candiates items set
def count_unique_items(all_items_list, items_subset_from_last_pass, support):
    
    result = []    
    if not items_subset_from_last_pass: # in "items_subset_from_last_pass" is empty 
        items_and_count = {}  
        for single_transaction in all_items_list:
            for single_item in single_transaction: # use dictionary count douplicate values
                items_and_count.setdefault(single_item, 0)
                items_and_count[single_item] += 1

        #print("Count of All Items:\n", dict(sorted(ht_item.items())))
        for (item, count) in items_and_count.items(): # store each item and their count in a list
            result.append([item, count])
    else:
        result = items_subset_from_last_pass # return items from items_subset_from_last_pass (old items set)item set
    return result # return 2d list of orignal item count 



# 4
# call by pass-one 
# return frequent items set according to support
def find_frequent_items(item_counts, support):
    itemset_size = len(item_counts[0]) - 1
    frequent_items = []
    for item in item_counts:
        if item[itemset_size] >= support:
            frequent_items.append(item[:-1])
    frequent_items.sort()
    return frequent_items



# 5
#call in both
# get frequent items in 2d list and complete itemset in 2d list
# convert itemset into sub item set n-1,n-3,n-4 so....
def generate_pairs(frequent_items, all_items_list, itemset_size):
    result = []
    frequent_singletons = get_single_list(frequent_items) # -> 6 return single sorted list from 2d frequent_items list
    for frequent_item in frequent_items:
        fip = {}
        for single_transaction in all_items_list: # one by one get 1d item list from 2d items list 
            if len(single_transaction) < itemset_size + 1: # itemset_size use for subset(1st time it's 3(2+1), than 4 ...)
                continue
            inside = True
            for item in frequent_item: # it's 2d list pass inner list one by one
                if item not in single_transaction: # thst single frequent item not in that specific orignal item subset                    
                    inside = False
                    break
            if inside == True:
                for item in single_transaction: # get lingle item from 1d list of items
                    if (item not in frequent_singletons) or (item in frequent_item): # add in dictionary if this item in "frequent_singllist"
                        continue
                    fip.setdefault(item, 0)
        keys = fip.keys()
        keys = sorted(keys)
        for key in keys: # items name are in keys list variable
            tmp = list(frequent_item)
            tmp.extend(key)
            tmp.sort()
            if tmp not in result:
                result.append(tmp)
        
    true_result = []
    for items in result:
        inside = True
        for i in range(len(items)):
            tmp = list(items)
            tmp.pop(i)
            if tmp not in frequent_items:
                inside = False # if not a "frequent_items"
                break
        if inside == True: # check result items in "frequent_items" and add in one by one 
            true_result.append(items)
    #print("\n\nsubset of items which support is above from min-support: \n", sorted(true_result))
    return sorted(true_result)



# 6
#return 1d sorted unique items list 
def get_single_list(itemsets):
    temp = {}
    for items in itemsets:
        for item in items:
            temp.setdefault(item, 0) # all items become keays and its can not duplicate
    keys = temp.keys()
    keys = sorted(keys)
    return keys



# 7
# call from 11
# return a bucket dictionary and map each subset into bucket index
def maping_pairs_bucket(pairs, all_items_list):
    pair_size = len(pairs[0])
    item_and_no = assign_numbering(pairs) # -> 8 return all pair with a sequence numbering in dictionary
    count_pairs(pairs, all_items_list) # -> 9 count pair and store count value in orignal pairs variable
    bucket = {} # key: bucket_no, value: pairs
    for pair in pairs:
        bucket_no = 1
        for i in range(pair_size): # 
            c = pair[i]
            bucket_no *= item_and_no[c] # multiplay with assigning sequence number
        bucket_no %= 7 # calculate index number
        bucket.setdefault(bucket_no, []) # add into dictionary
        bucket[bucket_no].append(pair)
    return dict(sorted(bucket.items()))



# 8
# call from 7
# get 2d list and return dictionary and with number 1 to so on..
def assign_numbering(pairs):
    item_and_no = {}
    number = 1
    for pair in pairs:      # get pair set from 2d list one by one  =O(n), since length of pair is constant
        for c in pair:    # get single from 1d list
            if c not in item_and_no.keys():
                item_and_no.setdefault(c, number)
                number += 1
    #print("\n\nAssign sequence number: \n", dict(sorted(item_and_no.items())))
    return dict(sorted(item_and_no.items()))



# 9
# call by 7
# get pairs and all_items_list as 2d list 
# store count value in orinal pairs 2d list variable
def count_pairs(pairs, all_items_list):
    # count the pair in all_items_list and add at the last index
    itemset_size = len(pairs[0])
    for pair in pairs:
        count = 0
        for single_transaction in all_items_list:
            if len(single_transaction) < itemset_size:
                continue
            inside = True
            for i in range(len(pair)):
                if pair[i] not in single_transaction:
                    inside = False
                    break
            if inside == True:
                count += 1
        pair.append(count)
    #print("\n\ncount each subset and their frequency at the last index: \n",pairs)

        
# 10
# call from 14
# get 2d list and create 1d list with all unique frequent items
def frequent_items_in_onelist(frequent_items):
#     print("\n\nfrequent_items_in_onelist:")
#     print("\nfrequent_items:", frequent_items)
    result = {}
    if len(frequent_items) > 1:
#         print("\nif len(frequent_items) > 1:")
        for items in frequent_items:
#             print("\nfor items in frequent_items:", items)
            if len(items) >= 1:
#                 print("\nif len(items) >= 1:", items)
                for item in items:
                    result.setdefault(item, 0)
            #result.setdefault(item, 0)
        result = list(result.keys())
    else:
        result = frequent_items[0]
                  
    return result

# 11
# call from 14
# return 2d list of frequent items pair
def generate_frequent_items_pair(fitems):
    pairs = []
    list_len= len(fitems)
    for i in range(list_len):

        if i+1 < list_len:
            pairs.append([fitems[i], fitems[i+1]])
            #pairs.append([fitems[i], fitems[i+1], fitems[(list_len - 1) - i]])
        pairs.append([fitems[(list_len - 1) - i],fitems[i]])

    return pairs




# 12
# call from 14
def roules_and_support_confidence_lift(items_pair, all_items_list):
    
    rule = {'rule': [], 'support' : [], 'confidence' : [], 'lift' : []}
    tolaTransactions = len(all_items_list)
    
# 12.1  
# call from 12
# return the frequency or support
    def count_frequency(pairs, all_items_list):
    # count the pair in all_items_list and add at the last index
        itemset_size = len(pairs[0])
        for pair in pairs:
            count = 0
            for single_transaction in all_items_list:
                if len(single_transaction) < itemset_size:
                    continue
                inside = True
                for i in range(len(pair)):
                    if pair[i] not in single_transaction:
                        inside = False
                        break
                if inside == True:
                    count += 1
            return count
# 12.2    
# call from 12
# add new rule and support_confidence_lift in dictionary
    def support_confidence_lift(a, b , ab):
        
        frequency_A = count_frequency([a], all_items_list) # -> 12.1 get frequency
        frequency_B = count_frequency([b], all_items_list) # -> 12.1 get frequency
        frequency_AB = count_frequency([ab], all_items_list) # -> 12.1 get frequency
        if frequency_AB < 2:
            return 0

        support_A = frequency_A / tolaTransactions # -> 12.1 get frequency
        support_B = frequency_B / tolaTransactions # -> 12.1 get frequency
        support_AB = frequency_AB / tolaTransactions
        
        try:
            r = str(a)[1:-1] + " -> " + str(b)[1:-1]
            s = support_AB
            c = frequency_AB / frequency_A               
            l = c / support_B 
        except ZeroDivisionError:
            return 0
        rule['rule'].append(r) 
        rule['support'].append(s)
        rule['confidence'].append(c)
        rule['lift'].append(l)


    for pair in items_pair:
        if len(pair) == 1:
            continue

        if len(pair) == 2:
            a = pair[:1]
            b = pair[1:]
            ab = pair
            support_confidence_lift(a, b , ab) # -> 12.2 get support_confidence_lift
#         if len(pair) == 3:  
#             length = (len(pair))
#             a = pair[:length]
#             b = pair[:length-1]
#             ab = pair 
#             support_confidence_lift(a, b , ab) # -> 12.2 get support_confidence_lift

    return rule



# 13
def my_apriory(all_items_list, support):

    frequent_items = []
    items_subset_from_last_pass = [] # store subset and their count

    # remove "NaN" from items list
    all_items_list = [[x for x in y if str(x) != 'nan'] for y in all_items_list]
    while 1:
        ans_one = pass_one(all_items_list, items_subset_from_last_pass, support)
        if not ans_one: # if not frequent item found
            break
        ans_two = pass_two(all_items_list, ans_one)
        frequent_items = ans_two[0]
        if len(ans_two) == 1: # if ans-two have not any subset for next frequent pair 
            break
        items_subset_from_last_pass = ans_two[2]
    return frequent_items



# 14
def generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, file_name):
    # remove "NaN" from items list
    all_items_list = [[x for x in y if str(x) != 'nan'] for y in all_items_list]

    f = frequent_items_in_onelist(frequent_items) # -> 10 send 2d list and get 1d unique items list
    f_pairs = generate_frequent_items_pair(f) # -> 11 return 2d list of frequent_items in pairs
    rule = roules_and_support_confidence_lift(f_pairs, all_items_list) # -> 13 get all rule and their support_confidence_lift
    
    # store all data into text file
    with open(file_name, 'w') as file:
        text = "rule, support, confidence, lift\n"
        for i in range(len(rule["rule"])):
            text += '[' + str(rule["rule"][i]) +']' + ', ' + str(rule["support"][i]) + ', ' + str(rule["confidence"][i]) + ', ' + str(rule["lift"][i]) + '\n'
        file.write(text + '\n')
        print("Result also save in text file successfully..!!")
        
    # pd.DataFrame(rule).reindex(pd.DataFrame(rule).rule.str.len().sort_values().index).reset_index(drop=True)
    df = pd.DataFrame(rule) # dictionary convert info dataframe 
    try:
        s = df.rule.str.len().sort_values().index # sort as rules base it's gove index number list  
        df = df.reindex(s) # sort according list
        df = df.reset_index(drop=True) # index number in range
    except:
        return df
    return df

# %% [markdown]
# # <center><h1 style="font-size:60px; color:green;">"First Dataset"</h1></center>
#
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5"> This is a simple dataset used for testing purposes and checking how the Apriori Algorithm works. This dataset is self define/defined by ourselves and we load this dataset from a text file and than store it into a list. After that we pass this to our Apriori Algorithm which wil return the frequent itemset according to our minimum support. After that we pass that frequent item list to our rule generate function which name is <b>"generate_role_and_measure_support_confidence_lift"</b> that will return a dataframe which contains the rules and their support, confidence and lift value. we run the code on this dataset three times with different Min_support value.</p>

# %%
# function for read text file and save it info a 2d list
def read_text(inputfile):
    inputdata = open(inputfile, 'r')
    all_items_list = []
    for line in inputdata:
        all_transaction = []
        for item in line: # or basket[:-1] to delete '\n'
            if item == ' ' or item == ',' or item == '\n':
                continue
            all_transaction.append(item)
        all_items_list.append(all_transaction)
    return all_items_list

all_items_list = read_text('dataset_1.txt')
all_items_list
# Out:
# [['d', 'e', 'a'],
#  ['d', 'e', 'c'],
#  ['d', 'b', 'e', 'f'],
#  ['e', 'c', 'a', 'd'],
#  ['b', 'g', 'i', 'f', 'a', 'c'],
#  ['f', 'g', 'e', 'c', 'a'],
#  ['b', 'g', 'i', 'f', 'a', 'c', 'e', 'd']]

# %%
len(all_items_list)
# Out:
# 7

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 2"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 2)
frequent_items
# Out:
# [['a', 'b', 'c', 'f', 'g', 'i']]

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'first_dataset_min_support_2.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +----+------------+-----------+--------------+----------+
# |    | rule       |   support |   confidence |     lift |
# |----+------------+-----------+--------------+----------|
# |  0 | 'a' -> 'b' |  0.285714 |     0.4      | 0.933333 |
# |  1 | 'i' -> 'a' |  0.285714 |     1        | 1.4      |
# |  2 | 'b' -> 'c' |  0.285714 |     0.666667 | 0.933333 |
# |  3 | 'g' -> 'b' |  0.285714 |     0.666667 | 1.55556  |
# |  4 | 'c' -> 'f' |  0.428571 |     0.6      | 1.05     |
# |  5 | 'f' -> 'c' |  0.428571 |     0.75     | 1.05     |
# |  6 | 'f' -> 'g' |  0.428571 |     0.75     | 1.75     |
# |  7 | 'c' -> 'f' |  0.428571 |     0.6      | 1.05     |
# |  8 | 'g' -> 'i' |  0.285714 |     0.666667 | 2.33333  |
# |  9 | 'b' -> 'g' |  0.285714 |     0.666667 | 1.55556  |
# | 10 | 'a' -> 'i' |  0.285714 |     0.4      | 1.4      |
# +----+------------+-----------+--------------+----------+

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 3"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 3)
frequent_items
# Out:
# [['a', 'c', 'f', 'g']]

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'first_dataset_min_support_3.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +----+------------+-----------+--------------+--------+
# |    | rule       |   support |   confidence |   lift |
# |----+------------+-----------+--------------+--------|
# |  0 | 'a' -> 'c' |  0.571429 |         0.8  |   1.12 |
# |  1 | 'g' -> 'a' |  0.428571 |         1    |   1.4  |
# |  2 | 'c' -> 'f' |  0.428571 |         0.6  |   1.05 |
# |  3 | 'f' -> 'c' |  0.428571 |         0.75 |   1.05 |
# |  4 | 'f' -> 'g' |  0.428571 |         0.75 |   1.75 |
# |  5 | 'c' -> 'f' |  0.428571 |         0.6  |   1.05 |
# |  6 | 'a' -> 'g' |  0.428571 |         0.6  |   1.4  |
# +----+------------+-----------+--------------+--------+

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 5"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 5)
frequent_items
# Out:
# [['d', 'e']]

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'first_dataset_min_support_5.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +----+------------+-----------+--------------+---------+
# |    | rule       |   support |   confidence |    lift |
# |----+------------+-----------+--------------+---------|
# |  0 | 'd' -> 'e' |  0.714286 |     1        | 1.16667 |
# |  1 | 'e' -> 'd' |  0.714286 |     0.833333 | 1.16667 |
# |  2 | 'd' -> 'e' |  0.714286 |     1        | 1.16667 |
# +----+------------+-----------+--------------+---------+

# %% [markdown]
# # <center><h1 style="font-size:60px; color:green;">"Second Dataset"</h1></center>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5"> It's a dummy dataset which have 50 instances and arround 20 unique items. We use this dataset because it's also a easy dataset which human can easily understand and we can measure the accuracy of our algorithm becaue it's a simple dataset. <p/>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5"> We load this dataset from a text file and than store it into a list and pass our Apriori Algorithm that wil return the frequent itemset according to our minimum support. After that we pass that frequent item list to our rule generate function which name is <b>"generate_role_and_measure_support_confidence_lift"</b> that eill return a dataframe whic contain the rules and their support, confidence and lift value. we run the code on this dataset three time with different Min_Support value. <p/>
# <br>
#
# <center><h1 style="font-size:35px; color:MidnightBlue;">"Read Data"</h1></center>

# %%
# function for read text file and save it info a 2d list
def read_text(inputfile):
    inputdata = open(inputfile, 'r')
    all_items_list = []
    for line in inputdata:
        all_transaction = []
        for item in line: # or basket[:-1] to delete '\n'
            if item == ' ' or item == ',' or item == '\n':
                continue
            all_transaction.append(item)
        all_items_list.append(all_transaction)
    return all_items_list

all_items_list = read_text('dataset_2.txt')
print(all_items_list)
# Out:
# [['a', 'h', 'e', 'd', 'i', 'b'], ['k', 'j', 'g', 'a', 'i', 'd'], ['a'], ['d', 'e', 'f', 'g', 'c', 'a', 'k', 'j', 't', 'o', 'p', 's'], ['j', 'k', 'l', 'h', 'd', 'e', 'a', 'g'], ['b', 'a', 'e', 'c', 'd'], ['g', 'k', 'e', 'j', 'c', 'a', 'd'], ['c', 'd', 'f', 'h', 'b'], ['b', 'a'], ['n', 'e', 'j', 'c', 'g', 'q', 'i', 'l', 'a', 'f', 'o', 'h'], ['i', 'r', 'n', 'p', 'o', 'k', 'l', 'e', 'g', 'm', 'b', 's', 'f', 'q'], ['g', 'c', 'q', 'e', 'b', 'h', 'm', 'i', 'p', 'l', 'n', 'a'], ['g', 'd', 'e', 'h', 'b', 'a', 'f'], ['c', 'd', 'b', 'a'], ['g', 'f', 'q', 'h', 'n', 'i', 'o', 'j', 'r', 'l', 'c', 'b'], ['h', 'c', 'o', 'e', 'l', 'a', 'm', 'k', 'f', 'i'], ['h', 'r', 'm', 'i', 't', 'l', 'g', 'f', 'j', 'c', 'n', 'p', 'k'], ['a', 'b', 'j', 'c', 'e', 'g', 'h', 'i', 'f'], ['l', 'n', 'o', 'a', 'j', 'd', 'e', 'i', 's', 'k', 'g', 'r'], ['j', 'g', 'f', 'm', 'l', 'h', 'n', 'i', 'o', 'k'], ['b', 'c', 'a'], ['g', 'a', 'e', 'd'], ['d', 'j', 'h', 'b', 'a', 'c'], ['f', 'r', 'n', 'j', 't', 'h', 'o', 'm', 'u', 'k', 
# ...

# %%
len(all_items_list)
# Out:
# 50

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 8"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 8)
frequent_items
# Out:
# [['a', 'c', 'e', 'f', 'i'],
#  ['c', 'f', 'g', 'l', 'n'],
#  ['c', 'f', 'h', 'l', 'n']]

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'second_dataset_min_support_8.txt')
print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +----+------------+-----------+--------------+----------+
# |    | rule       |   support |   confidence |     lift |
# |----+------------+-----------+--------------+----------|
# |  0 | 'a' -> 'c' |      0.48 |     0.685714 | 1.0084   |
# |  1 | 'n' -> 'h' |      0.24 |     0.666667 | 1.33333  |
# |  2 | 'e' -> 'l' |      0.26 |     0.481481 | 1.09428  |
# |  3 | 'l' -> 'n' |      0.32 |     0.727273 | 2.0202   |
# |  4 | 'f' -> 'g' |      0.34 |     0.607143 | 1.08418  |
# |  5 | 'g' -> 'l' |      0.3  |     0.535714 | 1.21753  |
# |  6 | 'i' -> 'i' |      0.48 |     1        | 2.08333  |
# |  7 | 'c' -> 'n' |      0.24 |     0.352941 | 0.980392 |
# |  8 | 'i' -> 'g' |      0.3  |     0.625    | 1.11607  |
# |  9 | 'f' -> 'i' |      0.34 |     0.607143 | 1.26488  |
# | 10 | 'l' -> 'e' |      0.26 |     0.590909 | 1.09428  |
# | 11 | 'e' -> 'f' |      0.36 |     0.666667 | 1.19048  |
# ...

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 10"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 10)
frequent_items
# Out:
# [['a', 'c', 'e', 'f', 'i']]

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'second_dataset_min_support_10.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +----+------------+-----------+--------------+---------+
# |    | rule       |   support |   confidence |    lift |
# |----+------------+-----------+--------------+---------|
# |  0 | 'a' -> 'c' |      0.48 |     0.685714 | 1.0084  |
# |  1 | 'i' -> 'a' |      0.36 |     0.75     | 1.07143 |
# |  2 | 'c' -> 'e' |      0.38 |     0.558824 | 1.03486 |
# |  3 | 'f' -> 'c' |      0.44 |     0.785714 | 1.15546 |
# |  4 | 'e' -> 'f' |      0.36 |     0.666667 | 1.19048 |
# |  5 | 'e' -> 'e' |      0.54 |     1        | 1.85185 |
# |  6 | 'f' -> 'i' |      0.34 |     0.607143 | 1.26488 |
# |  7 | 'c' -> 'f' |      0.44 |     0.647059 | 1.15546 |
# |  8 | 'a' -> 'i' |      0.36 |     0.514286 | 1.07143 |
# +----+------------+-----------+--------------+---------+

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 15"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 15)
frequent_items
# Out:
# [['a', 'c', 'd'],
#  ['a', 'c', 'e'],
#  ['a', 'c', 'f'],
#  ['a', 'd', 'e'],
#  ['c', 'f', 'h']]

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'second_dataset_min_support_15.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +----+------------+-----------+--------------+----------+
# |    | rule       |   support |   confidence |     lift |
# |----+------------+-----------+--------------+----------|
# |  0 | 'a' -> 'c' |      0.48 |     0.685714 | 1.0084   |
# |  1 | 'h' -> 'a' |      0.3  |     0.6      | 0.857143 |
# |  2 | 'c' -> 'd' |      0.44 |     0.647059 | 1.04364  |
# |  3 | 'f' -> 'c' |      0.44 |     0.785714 | 1.15546  |
# |  4 | 'd' -> 'e' |      0.38 |     0.612903 | 1.13501  |
# |  5 | 'e' -> 'd' |      0.38 |     0.703704 | 1.13501  |
# |  6 | 'e' -> 'f' |      0.36 |     0.666667 | 1.19048  |
# |  7 | 'd' -> 'e' |      0.38 |     0.612903 | 1.13501  |
# |  8 | 'f' -> 'h' |      0.38 |     0.678571 | 1.35714  |
# |  9 | 'c' -> 'f' |      0.44 |     0.647059 | 1.15546  |
# | 10 | 'a' -> 'h' |      0.3  |     0.428571 | 0.857143 |
# +----+------------+-----------+--------------+----------+

# %% [markdown]
# # <center><h1 style="font-size:60px; color:green;">"Third Dataset"</h1></center>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5"> It's a real dataset of a market. we copy this dataset from a website. It have more than 7000 instances and more than 100 items. We pass this dataset to our Apriory Algorithm and also pass the min_support vale to find the frequent items and than pass that frequent item list to second function <b>"generate_role_and_measure_support_confidence_lift"</b> to find the rules and calculete support, confidence and lift according to that rules. </p>
#
# <p style="font-family:Times New Roman (Headings CS);font-size:20px;line-height:1.5"> We will do this work three time with differet Min_Support value and due to that different support value will function will return the different frequent items list.</p>
# <br>
# <center><h1 style="font-size:35px; color:MidnightBlue;">"Read Data"</h1></center>

# %%
df = pd.read_csv('MarketData.csv', header = None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %% [markdown]
# <center><h1 style="font-size:35px; color:MidnightBlue;">"Convert Into A List"</h1></center>

# %%
all_items_list = []
for i in range(0, len(df)):
    all_items_list.append([str(df.values[i,j]) for j in range(0, 20)])
    
print(all_items_list[:5])
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil'], ['burgers', 'meatballs', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['chutney', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['turkey', 'avocado', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']]

# %%
len(all_items_list)
# Out:
# 7501

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 20"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 20)
print(frequent_items)
# Out:
# [['almonds'], ['antioxydant juice'], ['asparagus'], ['avocado'], ['babies food'], ['bacon'], ['barbecue sauce'], ['black tea'], ['blueberries'], ['body spray'], ['brownies'], ['bug spray'], ['burger sauce'], ['burgers'], ['butter'], ['cake'], ['candy bars'], ['carrots'], ['cauliflower'], ['cereals'], ['champagne'], ['chicken'], ['chili'], ['chocolate'], ['chocolate bread'], ['chutney'], ['cider'], ['clothes accessories'], ['cookies'], ['cooking oil'], ['corn'], ['cottage cheese'], ['dessert wine'], ['eggplant'], ['eggs'], ['energy bar'], ['energy drink'], ['escalope'], ['extra dark chocolate'], ['flax seed'], ['french fries'], ['french wine'], ['fresh bread'], ['fresh tuna'], ['fromage blanc'], ['frozen smoothie'], ['frozen vegetables'], ['gluten free bar'], ['grated cheese'], ['green beans'], ['green grapes'], ['green tea'], ['ground beef'], ['gums'], ['ham'], ['hand protein bar'], ['herb & pepper'], ['honey'], ['hot dogs'], ['ketchup'], ['light cream'], ['light mayo'], ['low fat yo
# ...

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'third_dataset_min_support_20.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +-----+-------------------------------------------+-------------+--------------+-----------+
# |     | rule                                      |     support |   confidence |      lift |
# |-----+-------------------------------------------+-------------+--------------+-----------|
# |   0 | 'gums' -> 'ham'                           | 0.000399947 |   0.029703   |  1.11961  |
# |   1 | 'soda' -> 'soup'                          | 0.000533262 |   0.0851064  |  1.68439  |
# |   2 | 'rice' -> 'salad'                         | 0.000266631 |   0.0141844  |  2.8756   |
# |   3 | 'pasta' -> 'eggs'                         | 0.00279963  |   0.177966   |  0.9903   |
# |   4 | 'eggs' -> 'pasta'                         | 0.00279963  |   0.0155786  |  0.9903   |
# |   5 | 'butter' -> 'cake'                        | 0.00293294  |   0.0973451  |  1.20096  |
# |   6 | 'honey' -> 'honey'                        | 0.0466604   |   0.983146   | 20.7151   |
# ...

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 30"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 30)
print(frequent_items)
# Out:
# [['almonds'], ['antioxydant juice'], ['asparagus'], ['avocado'], ['babies food'], ['bacon'], ['barbecue sauce'], ['black tea'], ['blueberries'], ['body spray'], ['brownies'], ['bug spray'], ['burger sauce'], ['burgers'], ['butter'], ['cake'], ['candy bars'], ['carrots'], ['cauliflower'], ['cereals'], ['champagne'], ['chicken'], ['chili'], ['chocolate'], ['chocolate bread'], ['chutney'], ['cider'], ['clothes accessories'], ['cookies'], ['cooking oil'], ['corn'], ['cottage cheese'], ['dessert wine'], ['eggplant'], ['eggs'], ['energy bar'], ['energy drink'], ['escalope'], ['extra dark chocolate'], ['flax seed'], ['french fries'], ['french wine'], ['fresh bread'], ['fresh tuna'], ['fromage blanc'], ['frozen smoothie'], ['frozen vegetables'], ['gluten free bar'], ['grated cheese'], ['green beans'], ['green grapes'], ['green tea'], ['ground beef'], ['gums'], ['ham'], ['hand protein bar'], ['herb & pepper'], ['honey'], ['hot dogs'], ['ketchup'], ['light cream'], ['light mayo'], ['low fat yo
# ...

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'third_dataset_min_support_30.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +-----+-------------------------------------------+-------------+--------------+-----------+
# |     | rule                                      |     support |   confidence |      lift |
# |-----+-------------------------------------------+-------------+--------------+-----------|
# |   0 | 'gums' -> 'ham'                           | 0.000399947 |   0.029703   |  1.11961  |
# |   1 | 'soda' -> 'soup'                          | 0.000533262 |   0.0851064  |  1.68439  |
# |   2 | 'rice' -> 'salad'                         | 0.000266631 |   0.0141844  |  2.8756   |
# |   3 | 'ketchup' -> 'ham'                        | 0.000266631 |   0.0606061  |  2.28445  |
# |   4 | 'ham' -> 'ketchup'                        | 0.000266631 |   0.0100503  |  2.28445  |
# |   5 | 'melons' -> 'milk'                        | 0.00226636  |   0.188889   |  1.45767  |
# |   6 | 'butter' -> 'cake'                        | 0.00293294  |   0.0973451  |  1.20096  |
# ...

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Executing Apriory Algorithm With Min_Support 60"</h1></center>

# %%
frequent_items =  my_apriory(all_items_list, 60)
print(frequent_items)
# Out:
# [['almonds'], ['antioxydant juice'], ['avocado'], ['bacon'], ['barbecue sauce'], ['black tea'], ['blueberries'], ['body spray'], ['brownies'], ['bug spray'], ['burgers'], ['butter'], ['cake'], ['candy bars'], ['carrots'], ['cereals'], ['champagne'], ['chicken'], ['chocolate'], ['cider'], ['clothes accessories'], ['cookies'], ['cooking oil'], ['cottage cheese'], ['eggplant'], ['eggs'], ['energy bar'], ['energy drink'], ['escalope'], ['extra dark chocolate'], ['flax seed'], ['french fries'], ['french wine'], ['fresh bread'], ['fresh tuna'], ['fromage blanc'], ['frozen smoothie'], ['frozen vegetables'], ['grated cheese'], ['green beans'], ['green grapes'], ['green tea'], ['ground beef'], ['gums'], ['ham'], ['herb & pepper'], ['honey'], ['hot dogs'], ['light cream'], ['light mayo'], ['low fat yogurt'], ['magazines'], ['meatballs'], ['melons'], ['milk'], ['mineral water'], ['mint'], ['muffins'], ['mushroom cream sauce'], ['nonfat milk'], ['oil'], ['olive oil'], ['pancakes'], ['parmesan ch
# ...

# %% [markdown]
# # <center><h1 style="font-size:30px; color:MidnightBlue;">"Finding Rules And Calculating Support, Confidence And Lift"</h1></center>

# %%
df = generate_role_and_measure_support_confidence_lift(frequent_items, all_items_list, 'third_dataset_min_support_60.txt')

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Result also save in text file successfully..!!
# +-----+-------------------------------------------+-------------+--------------+-----------+
# |     | rule                                      |     support |   confidence |      lift |
# |-----+-------------------------------------------+-------------+--------------+-----------|
# |   0 | 'gums' -> 'ham'                           | 0.000399947 |   0.029703   |  1.11961  |
# |   1 | 'gums' -> 'ham'                           | 0.000399947 |   0.029703   |  1.11961  |
# |   2 | 'ham' -> 'gums'                           | 0.000399947 |   0.0150754  |  1.11961  |
# |   3 | 'cider' -> 'rice'                         | 0.000399947 |   0.0379747  |  2.0202   |
# |   4 | 'rice' -> 'cider'                         | 0.000399947 |   0.0212766  |  2.0202   |
# |   5 | 'melons' -> 'milk'                        | 0.00226636  |   0.188889   |  1.45767  |
# |   6 | 'rice' -> 'salmon'                        | 0.00186642  |   0.0992908  |  2.33473  |
# ...

# %% [markdown]
# <center><h3 style="font-size:35px; color:red;">*_______THE END_______*</h3></center>
